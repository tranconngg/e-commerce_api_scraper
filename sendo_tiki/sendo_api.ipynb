# %%
import requests
import json

url = "https://searchlist-api.sendo.vn/web/products"
headers = {
    "authority": "searchlist-api.sendo.vn",
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "vi-VN,vi;q=0.9",
    "cookie": "_fbp=fb.1.1724426233605.22883982768552182; _gcl_au=1.1.2007905625.1724426234; _tt_enable_cookie=1; _ttp=S-xRZIqQLjeTzsWk7bAt32xfGNh; _ga_M8HGEHNMYC=GS1.1.1724475992.2.0.1724475992.0.0.0; client_id=8e240e85-83be-49a0-a9a1-63f0b346b47c; tracking_id=7f9b0016-9d51-41c9-b177-7170c3c5b588; __utma=147100981.786305503.1724426233.1724475977.1725271822.3; __utmc=147100981; __utmz=147100981.1725271822.3.3.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __utmt=1; _gid=GA1.2.1255608614.1725271822; _dc_gtm_UA-32891946-6=1; __utmb=147100981.2.10.1725271822; _ga_4GYS4WLTFH=GS1.2.1725271822.3.1.1725271826.56.0.0; _ga=GA1.1.786305503.1724426233; _ga_28PQS3WTN0=GS1.1.1725271822.1.1.1725271837.45.0.0",
    "origin": "https://www.sendo.vn",
    "referer": "https://www.sendo.vn/",
    "sec-ch-ua": '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"
}

params = {
    "source_page_id": "home",
    "source_pagetab_id": "0",
    "source_block_id": "shortcut_icon",
    "cabinet_list": "17729",
    "platform": "web",
    "page": "1",
    "size": "60",
    "sortType": "rank",
    "search_type": "",
    "app_ver": "2.43.0",
    "track_id": "7f9b0016-9d51-41c9-b177-7170c3c5b588",
    "search_suggestion_list": "",
    "search_textbox_string": "",
    "click_suggestion_index": ""
}

response = requests.get(url, headers=headers, params=params)
try:
    decoded_content = response.content.decode('utf-8', errors='replace')
    data = json.loads(decoded_content)
    print(json.dumps(data, indent=4, ensure_ascii=False))
except (ValueError, UnicodeDecodeError) as e:
    print(f"Error decoding JSON: {e}")
    print(decoded_content)
# Out:
# {
#     "data": [
#         {
#             "id": 116122456,
#             "name": "Máy mát xa cầm tay, súng massage trị liệu toàn thân Với 4 Đầu Thay Thế 6 Cấp Độ",
#             "category_path": "may-mat-xa-cam-tay-sung-massage-tri-lieu-toan-than-voi-4-dau-thay-the-6-cap-do-116122456.html",
#             "image": "https://media3.scdn.vn/img4/2023/11_02/CoMQLbja5nllDT0B8dyZ_simg_de2fe0_250x250_maxb.jpg",
#             "default_price_min": 199000,
#             "default_price_max": 199000,
#             "sale_price_min": 129000,
#             "sale_price_max": 129000,
#             "sale_percent": 36,
#             "sold": 162,
#             "order_count_text": "162",
#             "has_video": true,
#             "seller_admin_id": 575618,
#             "sku_user": "2010_116122456",
#             "active_event_frame": "flash_sale",
#             "status_new": 2,
#             "stock_status": 1,
#             "search_feed_type": "SKU",
#             "meta_data": {
# ...
